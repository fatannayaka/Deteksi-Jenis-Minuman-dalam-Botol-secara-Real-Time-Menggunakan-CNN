# %%
# ========================================
# 1. INSTALL ULTRALYTICS (sekali saja)
# ========================================
# !pip install ultralytics==8.3.6 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.0/882.0 kB 22.4 MB/s eta 0:00:00

# %%
# ========================================
# 2. UPLOAD ZIP DATASET ANDA (388 gambar)
# ========================================
from google.colab import files
uploaded = files.upload()        # pilih file ZIP dataset YOLOv8 Anda

# Unzip otomatis
# !unzip -q *.zip -d /content/dataset
# !ls /content/dataset             # pastikan ada: data.yaml  train/  valid/  test/
# Out:
#      <input type="file" id="files-759e9469-84ac-4157-8641-41d5cd60b12e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-759e9469-84ac-4157-8641-41d5cd60b12e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO
import os
os.environ["WANDB_MODE"] = "disabled"   # matikan wandb total

model = YOLO('yolov8n.pt')   # mulai dari pretrained

model.train(
    data='/content/dataset/data.yaml',
    epochs=50,               #  50
    imgsz=384,
    batch=32,                # cepat & aman di CPU
    device='cpu',
    patience=999,            # tidak boleh early stopping
    plots=True,              # grafik otomatis muncul
    save=True,
    save_period=10,
    name='kasir_50epoch_FINAL',   # folder hasil
    exist_ok=True,
    optimizer='AdamW',
    lr0=0.01,
    verbose=True
)
print("SELESAI 50 EPOCH! best.pt & semua grafik sudah ada")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 101MB/s]
# New https://pypi.org/project/ultralytics/8.3.230 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from IPython.display import Image, display

folder = "/content/runs/detect/kasir_50epoch_FINAL"

grafik = ["results.png", "confusion_matrix_normalized.png",
          "F1_curve.png", "PR_curve.png",
          "val_batch0_pred.jpg", "val_batch1_pred.jpg",
          "train_batch0.jpg"]

print("GRAFIK HASIL TRAINING 50 EPOCH:\n")
for g in grafik:
    path = f"{folder}/{g}"
    if os.path.exists(path):
        print(f"→ {g.upper()}")
        display(Image(filename=path))
    else:
        print(f"→ {g} belum ada")
# Out:
# GRAFIK HASIL TRAINING 50 EPOCH:
#
# → RESULTS.PNG
# → CONFUSION_MATRIX_NORMALIZED.PNG
# → F1_CURVE.PNG
# → PR_CURVE.PNG
# → VAL_BATCH0_PRED.JPG
# → VAL_BATCH1_PRED.JPG
# → TRAIN_BATCH0.JPG

# %%
# ========================================
# 5. DOWNLOAD SEMUA (MODEL + GRAFIK) SEKALIGUS
# ========================================
# !zip -r UAS_KASIR_50EPOCH_SELESAI.zip /content/runs/detect/kasir_50epoch_FINAL/
from google.colab import files
files.download("UAS_KASIR_50EPOCH_SELESAI.zip")
# Out:
# 	zip warning: name not matched: /content/runs/detect/kasir_50epoch_FINAL/
#
# zip error: Nothing to do! (try: zip -r UAS_KASIR_50EPOCH_SELESAI.zip . -i /content/runs/detect/kasir_50epoch_FINAL/)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1932595962.py in <cell line: 0>()
#       4 get_ipython().system('zip -r UAS_KASIR_50EPOCH_SELESAI.zip /content/runs/detect/kasir_50epoch_FINAL/')
#       5 from google.colab import files
# ----> 6 files.download("UAS_KASIR_50EPOCH_SELESAI.zip")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# ...
